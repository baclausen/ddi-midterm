# %% [markdown]
# ## Notebook file for Digital Piracy Analysis of US-Content

# %%
# Import libraries
import numpy as np
import pandas as pd
import midterm_functions as mf
import matplotlib.pyplot as plt
import seaborn as sns

# Import the data
df = pd.read_csv('../data/pirated_video.csv')

# %%
# Inspect original data
display(df.info())
display(df.head(3))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20548 entries, 0 to 20547
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       20548 non-null  int64
#  1   IMDb-rating      19707 non-null  float64
#  2   appropriate_for  11072 non-null  object
#  3   director         18610 non-null  object
#  4   downloads        20547 non-null  object
#  5   id               20548 non-null  int64
#  6   industry         20547 non-null  object
#  7   language         20002 non-null  object
#  8   posted_date      20547 non-null  object
#  9   release_date     20547 non-null  object
#  10  run_time         18780 non-null  object
#  11  storyline        18847 non-null  object
#  12  title            20547 non-null  object
#  13  views            20547 non-null  object
#  14  writer           18356 non-null  object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 2.4+ MB
# None
# ...

# %%
# Run our cleaning pipeline and inspect the results
df = mf.total_clean(df)
display(df.info())
display(df.head(3))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12194 entries, 0 to 12193
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               12194 non-null  object
#  1   director            12194 non-null  object
#  2   storyline           12194 non-null  object
#  3   run_time            12194 non-null  int64
#  4   appropriate_for     12194 non-null  object
#  5   IMDb-rating         12194 non-null  float64
#  6   release_date        12194 non-null  datetime64[ns]
#  7   posted_date         12194 non-null  datetime64[ns]
#  8   days_before_posted  12194 non-null  timedelta64[ns]
#  9   views               12194 non-null  int64
#  10  downloads           12194 non-null  int64
#  11  download_rate       12194 non-null  float64
# dtypes: datetime64[ns](2), float64(2), int64(3), object(4), timedelta64[ns](1)
# memory usage: 1.1+ MB
# None
#          title         director  \
# ...

# %%
# A variable of the 100 ranked by downloads
top_100 = df.sort_values(by="downloads", ascending=False).head(100)
top_100.head(10)
# Out:
#                                title                  director  \
# 4644                       Furious 7                 James Wan
# 7353          Avengers: Infinity War  Anthony Russo, Joe Russo
# 8320               Avengers: Endgame  Anthony Russo, Joe Russo
# 6447         The Fate of the Furious              F. Gary Gray
# 3214                Fast & Furious 6                Justin Lin
# 4710         Avengers: Age of Ultron               Joss Whedon
# 7034  Jumanji: Welcome to the Jungle               Jake Kasdan
# 2562                    The Avengers               Joss Whedon
# 4531            Fifty Shades of Grey        Sam Taylor-Johnson
# 6950                  Thor: Ragnarok             Taika Waititi
#
#                                               storyline  run_time  \
# 4644  Deckard Shaw seeks revenge against Dominic Tor...       137
# 7353  As the Avengers and their allies have continue...       149
# 8320  After the devastating events of Avengers: Infi...       181
# ...

# %%
# A variable of movies in the modern age. 24 June 1993 the first video server was active.
df_new = mf.modern_age_movies(df).reset_index(drop=True)
df_new.head()
# Out:
#                               title       director  \
# 0                 Dennis the Menace    Nick Castle
# 1              Sleepless in Seattle    Nora Ephron
# 2                       Hard Target       John Woo
# 3  Adventures Of Sonic The Hedgehog  Not available
# 4                 Striking Distance  Not available
#
#                                            storyline  run_time  \
# 0  When his parents have to go out of town, Denni...        94
# 1  After his wife Maggie passes away, Sam Baldwin...       105
# 2  A woman hires a drifter as her guide through N...        97
# 3                                      Not available        30
# 4  A serial killer is back in Pittsburgh to torme...       102
#
#   appropriate_for  IMDb-rating release_date posted_date days_before_posted  \
# 0              PG          5.6   1993-06-25  2014-03-17          7570 days
# 1              PG          6.8   1993-06-25  2014-12-09          7837 days
# ...
